# %%
import pickle
from collections import defaultdict
import requests, re
from tqdm import tqdm
import numpy as np

# %%
with open('word_dict.pickle', 'rb') as handle:
    word_dict = pickle.load(handle)
common_subtopics = set(word_dict.keys())

# %%
with open('clusters.pickle', 'rb') as handle:
    clusters = pickle.load(handle)
clustered_subtopics = list(clusters.values())

# %%
URL = "https://en.wikipedia.org/w/api.php"
TITLE = "Wikipedia:Lists of popular pages by WikiProject"
PARAMS = {
    'action': "parse",
    'page': TITLE,
    'prop': 'wikitext',
    'section': 1,
    'format': "json"
}
S = requests.Session()
res = S.get(url=URL, params=PARAMS)
data = res.json()
wikitext = data['parse']['wikitext']['*']
lines = wikitext.split('|-')
popular_pages = []
for line in lines:
        entry = line.split("|")        
        popular_list = re.sub("\[|\]|\n", '', entry[1])
        subject = re.sub("\[|\]|\n", '', entry[-1])
        if 'Computing' in subject:
            popular_pages.append(popular_list)
entries = []
for pages in tqdm(popular_pages):
    PARAMS = {
        'action': "parse",
        'page': pages,
        'prop': 'wikitext',
        'section': 1,
        'format': "json"
    }
    
    res = S.get(url=URL, params=PARAMS)
    data = res.json()
    
    wikitext = data['parse']['wikitext']['*']
    lines = wikitext.split('|-')
    for line in lines:
            entry = line.split("|")
            if len(entry) < 3:
                continue
            page_title = re.sub("\[|\]|\n", '', entry[2])
            importance = re.sub("\[|\]|\n", '', entry[-1])
            if importance != 'Low' and importance != 'Unknown':
                entries.append(page_title[1:].replace('%E2%80%93', '-').replace('&#039;', "'"))
# Out:
# 100%|█████████████████████████████████████| 601/601 [00:00<00:00, 198236.61it/s]
# 100%|███████████████████████████████████████████| 14/14 [00:19<00:00,  1.36s/it]

# %%
co_occurence = defaultdict(lambda: defaultdict(int))

# %%
URL = "https://en.wikipedia.org/w/api.php"
S = requests.Session()

for entry in tqdm(entries):
    list_of_sections = []
    TITLE = entry
    PARAMS = {
    'action': "parse",
    'page': TITLE,
    'prop': 'sections',
    'format': "json"
    }
    res = S.get(url=URL, params=PARAMS)
    data = res.json()
    bad_sections = ['See_also', 'Notes_and_references', 'External_links', 'References', 'Further_reading', 'Notes', 'Bibliography']
    try:
        data = data['parse']['sections']
    except:
        continue
    for idx, sections in enumerate(data):
        if int(sections['toclevel']) == 1:
            if sections['anchor'] not in bad_sections and sections['anchor'] in common_subtopics:
                list_of_sections.append(sections['anchor'])
    for i in range(len(list_of_sections)):
        for j in range(i+1, len(list_of_sections)):
            co_occurence[list_of_sections[i]][list_of_sections[j]] += 1
            co_occurence[list_of_sections[j]][list_of_sections[i]] += 1
# Out:
# 100%|███████████████████████████████████████| 4470/4470 [08:01<00:00,  9.28it/s]

# %%
len(co_occurence)
# Out:
# 148

# %%
co_occurence
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'Components': defaultdict(int,
#                          {'Platforms': 2,
#                           'Criticism': 3,
#                           'Version_history': 2,
#                           'Origins': 6,
#                           'Use': 2,
#                           'History': 35,
#                           'Versions': 2,
#                           'Examples': 5,
#                           'Market_share': 2,
#                           'Terminology': 4,
#                           'Development': 4,
#                           'Sources': 4,
#                           'Features': 8,
#                           'Adoption': 2,
#                           'Explanatory_notes': 2,
#                           'Overview': 2,
#                           'Standards': 2,
#                           'Impact': 2,
#                           'Motivation': 1,
#                           'Etymology': 3,
#                           'Applications': 5,
#                           'Types': 2,
#                           'Libraries': 1,
#                           'Security': 2,
#                           'Reception': 3,
#                           'Compatibility': 1,
#                           'Alternatives': 1,
#                           'Name': 3,
#                           'Implementations': 1,
#                           'Limitations': 1,
#                           'Derivatives': 2,
#                           'Technical_details': 1,
#                           'Controversies': 2,
#                           'Controversy': 2,
#                           'Advantages': 1,
#                           'Naming': 1,
#                           'Release_history': 2,
#                           'Design': 1,
#                           'Example': 1,
#                           'Releases': 1,
#                           'Editions': 1,
#                           'Implementation': 1,
#                           'Operation': 1,
#                           'Legacy': 1,
#                           'Purpose': 1}),
#              'Platforms': defaultdict(int,
#                          {'Components': 2,
#                           'Criticism': 5,
#                           'Version_history': 2,
#                           'History': 20,
#                           'Features': 16,
#                           'Technology': 4,
#                           'Reception': 17,
#                           'Storage': 3,
#                           'Usage': 3,
#                           'Implementation': 1,
#                           'Programming': 1,
#                           'Security': 3,
#                           'Release_history': 2,
#                           'Overview': 1,
#                           'Licensing': 1,
#                           'Internationalization': 2,
#                           'Naming': 1,
#                           'Types': 1,
#                           'Applications': 1,
#                           'Specifications': 1}),
#              'Criticism': defaultdict(int,
#                          {'Components': 3,
#                           'Platforms': 5,
#                           'Version_history': 3,
#                           'History': 115,
#                           'Books': 2,
#                           'History_and_development': 3,
#                           'Security': 6,
#                           'Market_share': 5,
#                           'System_requirements': 3,
#                           'Changes': 2,
#                           'Release_history': 3,
#                           'Features': 19,
#                           'Hardware': 1,
#                           'Software': 3,
#                           'Sales': 1,
#                           'Advantages': 3,
#                           'Compatibility': 4,
#                           'Origins': 4,
#                           'In_popular_culture': 4,
#                           'Litigation': 1,
#                           'Design': 3,
#                           'Name': 5,
#                           'Editions': 4,
#                           'Syntax': 4,
#                           'Implementations': 7,
#                           'Overview': 22,
#                           'Applications': 8,
#                           'Versions': 5,
#                           'Privacy': 5,
#                           'Trademark': 6,
#                           'Philosophy': 3,
#                           'Models': 2,
#                           'Types': 5,
#                           'Use': 6,
#                           'Gallery': 2,
#                           'Education': 4,
#                           'Structure': 9,
#                           'Terminology': 2,
#                           'Characteristics': 2,
#                           'Technologies': 2,
#                           'Adoption': 3,
#                           'Variants': 1,
#                           'Etymology': 5,
#                           'Implementation': 1,
#                           'Services': 4,
#                           'Conferences': 1,
#                           'Awards': 3,
#                           'Topics': 1,
#                           'Examples': 3,
#                           'Notable_examples': 1,
#                           'Usage': 5,
#                           'Alternatives': 1,
#                           'Controversies': 3,
#                           'Architecture': 2,
#                           'Production': 2,
#                           'Acquisitions': 2,
#                           'Products': 4,
#                           'Devices': 1,
#                           'Specifications': 1,
#                           'Reception': 8,
#                           'Development': 4,
#                           'Hardware_requirements': 1,
#                           'Uses': 1,
#                           'Motivation': 1,
#                           'Content': 3,
#                           'Development_tools': 1,
#                           'Availability': 2,
#                           'Example': 2,
#                           'Background': 2,
#                           'Licensing': 2,
#                           'Functionality': 1,
#                           'Corporate_affairs': 4,
#                           'Purpose': 2,
#                           'Timeline': 2,
#                           'Impact': 5,
#                           'Issues': 2,
#                           'Standards': 1,
#                           'Legacy': 2,
#                           'Citations': 2,
#                           'Influence': 1,
#                           'Mascot': 1,
#                           'Origin': 1,
#                           'Operation': 1,
#                           'Explanatory_notes': 1}),
#              'Version_history': defaultdict(int,
#                          {'Components': 2,
#                           'Platforms': 2,
#                           'Criticism': 3,
#                           'File_format': 2,
#                           'Cultural_impact': 2,
#                           'Overview': 10,
#                           'Features': 21,
#                           'Other_uses': 1,
#                           'Compatibility': 2,
#                           'Development': 4,
#                           'Software': 2,
#                           'History': 12,
#                           'Timeline': 1,
#                           'Technical_details': 2,
#                           'Syntax': 1,
#                           'Examples': 1,
#                           'Security': 3,
#                           'Hardware_requirements': 4,
#                           'Explanatory_notes': 4,
#                           'Introduction': 1,
#                           'Variants': 1,
#                           'Function': 2,
#                           'License': 2,
#                           'Derivatives': 2,
#                           'Design': 1,
#                           'Background': 1,
#                           'Problems': 1,
#                           'Example': 1,
#                           'Main_features': 1,
#                           'Licensing': 3,
#                           'Tools': 3,
#                           'Limitations': 2,
#                           'History_and_development': 2,
#                           'Supported_devices': 2,
#                           'Devices': 1,
#                           'Issues': 2,
#                           'Releases': 1,
#                           'Reception': 2,
#                           'Specifications': 1,
#                           'Use': 1,
#                           'Uses': 1,
#                           'Architecture': 1}),
#              'History': defaultdict(int,
#                          {'Architecture': 45,
#                           'Features': 334,
#                           'Release_history': 37,
#                           'Reception': 215,
#                           'Functionality': 17,
#                           'Implementation': 37,
#                           'Hardware': 40,
#                           'Development': 58,
#                           'Security_and_privacy': 14,
#                           'Devices': 10,
#                           'Usage': 54,
#                           'Books': 8,
#                           'Criticism': 115,
#                           'Software': 39,
#                           'Timeline': 22,
#                           'Specifications': 25,
#                           'Issues': 13,
#                           'Controversy': 23,
#                           'System_features': 18,
#                           'App_features': 18,
#                           'Supported_devices': 24,
#                           'Programming': 7,
#                           'System_requirements': 7,
#                           'Sales': 12,
#                           'Design': 92,
#                           'Etymology': 31,
#                           'Purpose': 11,
#                           'Security': 77,
#                           'Description': 42,
#                           'Overview': 151,
#                           'Advantages': 15,
#                           'Compatibility': 15,
#                           'Censorship': 18,
#                           'Internationalization': 6,
#                           'Technical_details': 14,
#                           'Content': 30,
#                           'Legacy': 23,
#                           'Programming_languages': 5,
#                           'General': 1,
#                           'Technology': 44,
#                           'Platforms': 20,
#                           'Problems': 17,
#                           'Influence': 10,
#                           'Syntax': 43,
#                           'Technologies': 21,
#                           'Acquisitions': 20,
#                           'Litigation': 8,
#                           'Controversies': 67,
#                           'Availability': 18,
#                           'License': 17,
#                           'Implementations': 64,
#                           'Models': 8,
#                           'Interface': 5,
#                           'Market_share': 20,
#                           'Functions': 6,
#                           'Critical_reception': 5,
#                           'Applications': 126,
#                           'Editions': 18,
#                           'Changes': 4,
#                           'Gallery': 9,
#                           'Impact': 23,
#                           'Mitigation': 16,
#                           'Versions': 39,
#                           'Background': 15,
#                           'Naming': 18,
#                           'Function': 10,
#                           'Components': 35,
#                           'Limitations': 39,
#                           'In_popular_culture': 35,
#                           'Version_history': 12,
#                           'Details': 4,
#                           'Other_uses': 8,
#                           'File_format': 7,
#                           'Services': 30,
#                           'Criticisms': 19,
#                           'Products': 25,
#                           'Name': 19,
#                           'Development_tools': 8,
#                           'Hardware_requirements': 1,
#                           'Operation': 34,
#                           'Motivation': 7,
#                           'Tools': 19,
#                           'Trademark': 10,
#                           'Philosophy': 11,
#                           'Explanatory_notes': 15,
#                           'Citations': 12,
#                           'Sources': 43,
#                           'Characteristics': 27,
#                           'Libraries': 9,
#                           'Uses': 49,
#                           'Popularity': 12,
#                           'Types': 72,
#                           'Examples': 81,
#                           'Topics': 7,
#                           'Structure': 30,
#                           'Standards': 17,
#                           'Derivatives': 15,
#                           'Mascot': 10,
#                           'Licensing': 43,
#                           'Use': 24,
#                           'Alternatives': 14,
#                           'Adoption': 38,
#                           'Education': 8,
#                           'Releases': 16,
#                           'Storage': 6,
#                           'Formal_definition': 5,
#                           'Properties': 17,
#                           'Conferences': 13,
#                           'Variants': 19,
#                           'Example': 23,
#                           'Terminology': 27,
#                           'Production': 5,
#                           'Theory': 6,
#                           'Notable_examples': 2,
#                           'Introduction': 13,
#                           'Publications': 6,
#                           'Awards': 15,
#                           'Corporate_affairs': 23,
#                           'Criticism_and_controversies': 12,
#                           'Privacy': 7,
#                           'Legality': 5,
#                           'Operating_system_support': 4,
#                           'Marketing': 10,
#                           'Release': 2,
#                           'Games': 8,
#                           'Cultural_impact': 4,
#                           'Origin': 2,
#                           'Media': 4,
#                           'Philanthropy': 1,
#                           'User_interface': 8,
#                           'Technical_specifications': 2,
#                           'Deployment': 4,
#                           'Main_features': 10,
#                           'Career': 1}),
#              'Architecture': defaultdict(int,
#                          {'History': 45,
#                           'Features': 14,
#                           'Release_history': 3,
#                           'Reception': 8,
#                           'Timeline': 2,
#                           'Introduction': 1,
#                           'Characteristics': 9,
#                           'Security_and_privacy': 5,
#                           'Technologies': 3,
#                           'Applications': 7,
#                           'In_popular_culture': 3,
#                           'Criticism': 2,
#                           'Licensing': 2,
#                           'Editions': 5,
#                           'Use': 2,
#                           'Uses': 2,
#                           'Security': 2,
#                           'Limitations': 7,
#                           'Advantages': 1,
#                           'Services': 2,
#                           'Development': 2,
#                           'User_interface': 2,
#                           'System_requirements': 2,
#                           'Legacy': 2,
#                           'Etymology': 2,
#                           'Products': 2,
#                           'Main_features': 1,
#                           'Deployment': 1,
#                           'Compatibility': 1,
#                           'Versions': 1,
#                           'Sources': 4,
#                           'Availability': 1,
#                           'Usage': 1,
#                           'Overview': 2,
#                           'Terminology': 1,
#                           'Examples': 2,
#                           'Example': 2,
#                           'Implementation': 1,
#                           'Version_history': 1}),
#              'Features': defaultdict(int,
#                          {'History': 334,
#                           'Architecture': 14,
#                           'Release_history': 27,
#                           'Reception': 104,
#                           'Hardware': 13,
#                           'Development': 44,
#                           'Security_and_privacy': 7,
#                           'Devices': 6,
#                           'Usage': 13,
#                           'System_requirements': 13,
#                           'Criticism': 19,
#                           'Timeline': 14,
#                           'Advantages': 3,
#                           'Compatibility': 5,
#                           'General': 6,
#                           'Models': 2,
#                           'Technology': 8,
#                           'Platforms': 16,
#                           'Market_share': 9,
#                           'Critical_reception': 4,
#                           'Issues': 4,
#                           'Version_history': 21,
#                           'Availability': 7,
#                           'Gallery': 2,
#                           'Supported_devices': 5,
#                           'Other_uses': 4,
#                           'Limitations': 18,
#                           'Controversy': 9,
#                           'Variants': 8,
#                           'Design': 13,
#                           'Specifications': 3,
#                           'File_format': 1,
#                           'Programming_languages': 1,
#                           'Software': 6,
#                           'In_popular_culture': 4,
#                           'Trademark': 4,
#                           'Syntax': 6,
#                           'Security': 20,
#                           'Development_tools': 4,
#                           'Implementations': 14,
#                           'Examples': 7,
#                           'Components': 8,
#                           'Adoption': 11,
#                           'Explanatory_notes': 5,
#                           'Implementation': 6,
#                           'Applications': 13,
#                           'Functions': 4,
#                           'Licensing': 13,
#                           'Mascot': 4,
#                           'Storage': 3,
#                           'Versions': 13,
#                           'Legality': 2,
#                           'Editions': 6,
#                           'Background': 4,
#                           'Releases': 11,
#                           'Operating_system_support': 2,
#                           'Technical_details': 1,
#                           'Technical_specifications': 1,
#                           'Sales': 1,
#                           'Introduction': 1,
#                           'Uses': 7,
#                           'License': 8,
#                           'Derivatives': 8,
#                           'Products': 1,
#                           'Overview': 18,
#                           'Sources': 1,
#                           'Conferences': 2,
#                           'Censorship': 1,
#                           'Operation': 3,
#                           'Popularity': 8,
#                           'Production': 1,
#                           'Technologies': 2,
#                           'User_interface': 2,
#                           'Tools': 2,
#                           'Interface': 1,
#                           'Functionality': 2,
#                           'Privacy': 5,
#                           'Properties': 1,
#                           'Naming': 2,
#                           'Description': 3,
#                           'Release': 3,
#                           'Internationalization': 1,
#                           'Criticisms': 1,
#                           'Awards': 1,
#                           'Deployment': 2,
#                           'Content': 6,
#                           'Services': 4,
#                           'Structure': 2,
#                           'Controversies': 4,
#                           'Etymology': 2,
#                           'Impact': 1,
#                           'Legacy': 2,
#                           'Corporate_affairs': 1,
#                           'Books': 1,
#                           'Use': 1,
#                           'Problems': 1,
#                           'Characteristics': 1,
#                           'Hardware_requirements': 1,
#                           'Litigation': 1,
#                           'Influence': 1,
#                           'Games': 1}),
#              'Release_history': defaultdict(int,
#                          {'History': 37,
#                           'Architecture': 3,
#                           'Features': 27,
#                           'Reception': 20,
#                           'Changes': 8,
#                           'System_requirements': 21,
#                           'Criticism': 3,
#                           'Applications': 2,
#                           'Overview': 6,
#                           'User_interface': 2,
#                           'Timeline': 1,
#                           'Design': 3,
#                           'License': 3,
#                           'System_features': 1,
#                           'App_features': 1,
#                           'Security': 2,
#                           'Compatibility': 2,
#                           'Legacy': 2,
#                           'Development': 5,
#                           'Limitations': 1,
#                           'Marketing': 1,
#                           'Name': 2,
#                           'Syntax': 2,
#                           'Platforms': 2,
#                           'Development_tools': 1,
#                           'Availability': 1,
#                           'Interface': 1,
#                           'Gallery': 1,
#                           'Criticisms': 2,
#                           'Devices': 2,
#                           'Technology': 1,
#                           'Philosophy': 1,
#                           'Adoption': 1,
#                           'Licensing': 1,
#                           'Internationalization': 3,
#                           'Hardware': 2,
#                           'General': 2,
#                           'Operating_system_support': 3,
#                           'Components': 2,
#                           'Naming': 1,
#                           'Production': 1,
#                           'Critical_reception': 1,
#                           'Controversy': 1,
#                           'Implementations': 1,
#                           'Types': 1,
#                           'Derivatives': 1,
#                           'Usage': 1}),
#              'Reception': defaultdict(int,
#                          {'History': 215,
#                           'Architecture': 8,
#                           'Features': 104,
#                           'Release_history': 20,
#                           'Hardware': 14,
#                           'Development': 39,
#                           'Security_and_privacy': 6,
#                           'Devices': 4,
#                           'Specifications': 23,
#                           'Software': 11,
#                           'Models': 4,
#                           'Controversies': 10,
#                           'Issues': 7,
#                           'Timeline': 17,
#                           'Sales': 4,
#                           'System_requirements': 20,
#                           'Applications': 9,
#                           'Changes': 6,
#                           'Design': 21,
#                           'Controversy': 1,
#                           'Overview': 26,
#                           'User_interface': 4,
#                           'Programming_languages': 2,
#                           'General': 1,
#                           'Description': 4,
#                           'Technology': 12,
#                           'Platforms': 17,
#                           'Influence': 3,
#                           'Availability': 4,
#                           'Gameplay': 15,
#                           'Release': 11,
#                           'Legacy': 20,
#                           'System_features': 12,
#                           'App_features': 12,
#                           'Storage': 4,
#                           'License': 2,
#                           'Security': 5,
#                           'Compatibility': 1,
#                           'Technical_specifications': 2,
#                           'Plot': 9,
#                           'Problems': 11,
#                           'Supported_devices': 13,
#                           'Background': 9,
#                           'Impact': 5,
#                           'Naming': 1,
#                           'Games': 4,
#                           'Functions': 1,
#                           'Tools': 3,
#                           'Examples': 3,
#                           'Licensing': 4,
#                           'Other_uses': 3,
#                           'Mascot': 3,
#                           'Usage': 5,
#                           'Versions': 2,
#                           'Components': 3,
#                           'Editions': 6,
#                           'Products': 2,
#                           'Criticisms': 2,
#                           'Criticism': 8,
#                           'Hardware_requirements': 2,
#                           'Limitations': 8,
#                           'Explanatory_notes': 2,
#                           'Uses': 1,
#                           'Content': 3,
#                           'Marketing': 5,
#                           'Derivatives': 4,
#                           'Production': 19,
#                           'Adoption': 5,
#                           'Origins': 1,
#                           'Sources': 2,
#                           'Gallery': 1,
#                           'Functionality': 4,
#                           'Variants': 2,
#                           'Internationalization': 2,
#                           'Technical_details': 1,
#                           'Types': 1,
#                           'Privacy': 1,
#                           'Operation': 6,
#                           'Cultural_impact': 6,
#                           'Programming': 2,
#                           'Publications': 4,
#                           'Citations': 1,
#                           'Books': 2,
#                           'Litigation': 4,
#                           'Market_share': 3,
#                           'In_popular_culture': 3,
#                           'Terminology': 1,
#                           'Media': 1,
#                           'Origin': 2,
#                           'Awards': 1,
#                           'Releases': 3,
#                           'Version_history': 2,
#                           'Deployment': 1,
#                           'Use': 1,
#                           'Function': 1}),
#              'Functionality': defaultdict(int,
#                          {'History': 17,
#                           'Implementation': 5,
#                           'Overview': 3,
#                           'Security': 3,
#                           'Examples': 2,
#                           'Features': 2,
#                           'Design': 2,
#                           'User_interface': 2,
#                           'Reception': 4,
#                           'Controversies': 1,
#                           'Availability': 1,
#                           'Criticism': 1,
#                           'Technology': 3,
#                           'Adoption': 1,
#                           'Awards': 1,
#                           'Development': 1}),
#              'Implementation': defaultdict(int,
#                          {'History': 37,
#                           'Functionality': 5,
#                           'Origin': 4,
#                           'Characteristics': 7,
#                           'Motivation': 2,
#                           'Applications': 10,
#                           'Properties': 2,
#                           'Usage': 4,
#                           'Variants': 1,
#                           'Features': 6,
#                           'Use': 2,
#                           'In_popular_culture': 2,
#                           'Examples': 10,
#                           'Limitations': 4,
#                           'Libraries': 1,
#                           'Criticism': 1,
#                           'Implementations': 1,
#                           'Introduction': 2,
#                           'Citations': 1,
#                           'Structure': 5,
#                           'Theory': 1,
#                           'Types': 1,
#                           'Gallery': 4,
#                           'Example': 5,
#                           'Models': 1,
#                           'Sources': 5,
#                           'Formal_definition': 1,
#                           'Background': 4,
#                           'Terminology': 4,
#                           'Uses': 5,
#                           'Etymology': 1,
#                           'Security': 2,
#                           'Overview': 4,
#                           'Design': 3,
#                           'Legacy': 1,
#                           'Platforms': 1,
#                           'Programming': 1,
#                           'Alternatives': 1,
#                           'Description': 1,
#                           'Adoption': 4,
#                           'Services': 1,
#                           'Purpose': 2,
#                           'Architecture': 1,
#                           'Editions': 1,
#                           'Components': 1,
#                           'Operation': 1,
#                           'Functions': 1,
#                           'Development': 1,
#                           'Career': 1}),
#              'Hardware': defaultdict(int,
#                          {'History': 40,
#                           'Features': 13,
#                           'Development': 9,
#                           'Security_and_privacy': 5,
#                           'Reception': 14,
#                           'Devices': 2,
#                           'Production': 1,
#                           'Models': 4,
#                           'Software': 27,
#                           'Specifications': 2,
#                           'Controversies': 1,
#                           'Etymology': 6,
#                           'Sales': 6,
#                           'Criticism': 1,
#                           'Legacy': 2,
#                           'Technical_specifications': 1,
#                           'Timeline': 1,
#                           'Products': 1,
#                           'Litigation': 1,
#                           'Overview': 7,
#                           'Types': 5,
#                           'Sources': 4,
#                           'Theory': 2,
#                           'Applications': 7,
#                           'Limitations': 2,
#                           'Conferences': 2,
#                           'Background': 2,
#                           'Licensing': 3,
#                           'Other_uses': 3,
#                           'Mascot': 3,
#                           'Uses': 3,
#                           'Alternatives': 1,
#                           'Use': 2,
#                           'Terminology': 1,
#                           'Release': 1,
#                           'Games': 1,
#                           'Explanatory_notes': 1,
#                           'Operation': 2,
#                           'Purpose': 1,
#                           'Security': 2,
#                           'User_interface': 1,
#                           'Design': 3,
#                           'Storage': 1,
#                           'Marketing': 1,
#                           'Versions': 1,
#                           'Internationalization': 2,
#                           'Release_history': 2,
#                           'Services': 1,
#                           'Variants': 1,
#                           'Critical_reception': 1,
#                           'Advantages': 1,
#                           'Problems': 1,
#                           'Awards': 1}),
#              'Development': defaultdict(int,
#                          {'History': 58,
#                           'Features': 44,
#                           'Hardware': 9,
#                           'Security_and_privacy': 5,
#                           'Reception': 39,
#                           'Devices': 2,
#                           'Releases': 9,
#                           'Specifications': 4,
#                           'Software': 3,
#                           'Models': 1,
#                           'Controversies': 2,
#                           'Gameplay': 13,
#                           'Release': 6,
#                           'Plot': 4,
#                           'Legacy': 9,
#                           'In_popular_culture': 1,
#                           'Release_history': 5,
#                           'Technical_specifications': 1,
#                           'Version_history': 4,
#                           'Overview': 2,
#                           'Libraries': 3,
#                           'Implementations': 4,
#                           'Naming': 7,
#                           'Popularity': 3,
#                           'Uses': 12,
#                           'Origins': 4,
#                           'Terminology': 4,
#                           'Components': 4,
#                           'Sources': 4,
#                           'Alternatives': 3,
#                           'Licensing': 12,
#                           'Other_uses': 3,
#                           'Mascot': 3,
#                           'Design': 5,
#                           'System_requirements': 7,
#                           'Versions': 3,
#                           'Structure': 2,
#                           'Editions': 3,
#                           'Hardware_requirements': 3,
#                           'Criticism': 4,
#                           'License': 4,
#                           'Derivatives': 5,
#                           'Architecture': 2,
#                           'User_interface': 3,
#                           'Name': 4,
#                           'Security': 8,
#                           'Applications': 4,
#                           'Functions': 1,
#                           'Limitations': 2,
#                           'Supported_devices': 3,
#                           'Market_share': 2,
#                           'Use': 2,
#                           'Example': 2,
#                           'Philosophy': 1,
#                           'Adoption': 1,
#                           'Variants': 2,
#                           'Availability': 2,
#                           'Trademark': 1,
#                           'Cultural_impact': 1,
#                           'Games': 1,
#                           'Explanatory_notes': 1,
#                           'Controversy': 1,
#                           'Types': 2,
#                           'Usage': 1,
#                           'Functionality': 1,
#                           'Implementation': 1}),
#              'Security_and_privacy': defaultdict(int,
#                          {'History': 14,
#                           'Features': 7,
#                           'Hardware': 5,
#                           'Development': 5,
#                           'Reception': 6,
#                           'Devices': 2,
#                           'System_features': 1,
#                           'App_features': 1,
#                           'Supported_devices': 1,
#                           'Characteristics': 5,
#                           'Architecture': 5,
#                           'Licensing': 3,
#                           'Other_uses': 3,
#                           'Mascot': 3,
#                           'Products': 1,
#                           'Etymology': 2,
#                           'Technology': 2}),
#              'Devices': defaultdict(int,
#                          {'History': 10,
#                           'Features': 6,
#                           'Hardware': 2,
#                           'Development': 2,
#                           'Security_and_privacy': 2,
#                           'Reception': 4,
#                           'Specifications': 1,
#                           'Criticism': 1,
#                           'Design': 1,
#                           'Security': 1,
#                           'Standards': 1,
#                           'Applications': 3,
#                           'Impact': 1,
#                           'Technical_specifications': 1,
#                           'Software': 1,
#                           'Timeline': 1,
#                           'Release_history': 2,
#                           'Criticisms': 2,
#                           'Version_history': 1,
#                           'Overview': 1,
#                           'Other_uses': 1}),
#              'Usage': defaultdict(int,
#                          {'History': 54,
#                           'Features': 13,
#                           'Software': 2,
#                           'Timeline': 2,
#                           'Formal_definition': 2,
#                           'Example': 3,
#                           'Properties': 2,
#                           'Implementation': 4,
#                           'Overview': 8,
#                           'Production': 3,
#                           'Examples': 11,
#                           'Structure': 1,
#                           'Criticism': 5,
#                           'Alternatives': 3,
#                           'Platforms': 3,
#                           'Reception': 5,
#                           'Purpose': 1,
#                           'Design': 3,
#                           'Security': 3,
#                           'Operation': 3,
#                           'Implementations': 4,
#                           'Terminology': 2,
#                           'File_format': 2,
#                           'Types': 1,
#                           'Topics': 1,
#                           'Content': 3,
#                           'Uses': 1,
#                           'Name': 1,
#                           'Technical_details': 2,
#                           'Licensing': 3,
#                           'Variants': 3,
#                           'Limitations': 2,
#                           'Technology': 5,
#                           'Origins': 2,
#                           'Architecture': 1,
#                           'Origin': 3,
#                           'Notable_examples': 2,
#                           'Criticism_and_controversies': 2,
#                           'Corporate_affairs': 3,
#                           'Influence': 1,
#                           'Mascot': 1,
#                           'Background': 1,
#                           'Mitigation': 1,
#                           'Sources': 1,
#                           'Applications': 1,
#                           'Development': 1,
#                           'Release_history': 1,
#                           'Derivatives': 1,
#                           'Description': 1,
#                           'Explanatory_notes': 1}),
#              'Background': defaultdict(int,
#                          {'Personal_life': 3,
#                           'Honors_and_awards': 3,
#                           'In_popular_culture': 4,
#                           'Design': 2,
#                           'Interface': 2,
#                           'History': 15,
#                           'Impact': 2,
#                           'Reception': 9,
#                           'Legacy': 5,
#                           'Timeline': 1,
#                           'Etymology': 5,
#                           'Standards': 4,
#                           'Software': 6,
#                           'Overview': 4,
#                           'Formal_definition': 3,
#                           'Naming': 2,
#                           'Properties': 5,
#                           'Example': 3,
#                           'Examples': 6,
#                           'Hardware': 2,
#                           'Variants': 4,
#                           'Uses': 4,
#                           'Applications': 2,
#                           'Terminology': 4,
#                           'Structure': 4,
#                           'Implementation': 4,
#                           'Sources': 4,
#                           'Features': 4,
#                           'Security': 4,
#                           'Releases': 3,
#                           'Explanatory_notes': 1,
#                           'Issues': 1,
#                           'Models': 1,
#                           'Technical_specifications': 1,
#                           'Limitations': 1,
#                           'Sales': 1,
#                           'Adoption': 2,
#                           'Version_history': 1,
#                           'Problems': 1,
#                           'Specifications': 1,
#                           'Operating_system_support': 1,
#                           'Operation': 3,
#                           'Description': 1,
#                           'Criticisms': 1,
#                           'Controversies': 1,
#                           'Criticism': 2,
#                           'Types': 1,
#                           'Characteristics': 1,
#                           'Use': 1,
#                           'Theory': 1,
#                           'Production': 2,
#                           'Popularity': 1,
#                           'Death': 1,
#                           'Plot': 1,
#                           'Games': 1,
#                           'Mitigation': 1,
#                           'Usage': 1,
#                           'Functions': 1,
#                           'Versions': 1}),
#              'Personal_life': defaultdict(int,
#                          {'Background': 3,
#                           'Honors_and_awards': 10,
#                           'In_popular_culture': 4,
#                           'Early_life_and_education': 46,
#                           'Career': 54,
#                           'Awards_and_honors': 8,
#                           'Early_life': 37,
#                           'Philanthropy': 13,
#                           'Other': 1,
#                           'Career_and_research': 8,
#                           'Awards': 10,
#                           'Biography': 5,
#                           'Programming': 3,
#                           'Publications': 6,
#                           'Books': 5,
#                           'Sources': 2,
#                           'Legacy': 2,
#                           'Explanatory_notes': 1,
#                           'Death': 1,
#                           'Education': 4,
#                           'Citations': 1,
#                           'Controversies': 1}),
#              'Honors_and_awards': defaultdict(int,
#                          {'Background': 3,
#                           'Personal_life': 10,
#                           'In_popular_culture': 3,
#                           'Early_life': 6,
#                           'Career': 4,
#                           'Philanthropy': 2,
#                           'Early_life_and_education': 1,
#                           'Biography': 1,
#                           'Controversy': 1}),
#              'In_popular_culture': defaultdict(int,
#                          {'Background': 4,
#                           'Personal_life': 4,
#                           'Honors_and_awards': 3,
#                           'Development': 1,
#                           'Criticism': 4,
#                           'History': 35,
#                           'Limitations': 3,
#                           'Legacy': 1,
#                           'Technical_specifications': 1,
#                           'Timeline': 2,
#                           'Features': 4,
#                           'Specifications': 1,
#                           'Design': 5,
#                           'Characteristics': 5,
#                           'Architecture': 3,
#                           'Technologies': 7,
#                           'Applications': 6,
#                           'Implementation': 2,
#                           'Use': 5,
#                           'Origins': 3,
#                           'Terminology': 2,
#                           'Types': 3,
#                           'Criticisms': 2,
#                           'Biography': 1,
#                           'Publications': 1,
#                           'Explanatory_notes': 2,
#                           'Early_life': 1,
#                           'Education': 1,
#                           'Philanthropy': 1,
#                           'Operation': 1,
#                           'Standards': 2,
#                           'Market_share': 1,
#                           'Security': 2,
#                           'Censorship': 5,
#                           'License': 1,
#                           'Examples': 1,
#                           'Versions': 3,
#                           'Controversies': 4,
#                           'Products': 1,
#                           'Function': 2,
#                           'Reception': 3,
#                           'Popularity': 1,
#                           'Awards': 1,
#                           'Influence': 1,
#                           'Advantages': 1,
#                           'Overview': 1}),
#              'Books': defaultdict(int,
#                          {'History': 8,
#                           'Criticism': 2,
#                           'Examples': 1,
#                           'Personal_life': 5,
#                           'Early_life': 4,
#                           'Philanthropy': 1,
#                           'Early_life_and_education': 2,
#                           'Career': 2,
#                           'Media': 1,
#                           'Reception': 2,
#                           'Content': 1,
#                           'Features': 1,
#                           'Awards': 1,
#                           'Biography': 1}),
#              'Releases': defaultdict(int,
#                          {'Development': 9,
#                           'History': 16,
#                           'Overview': 7,
#                           'Technical_details': 3,
#                           'Background': 3,
#                           'Features': 11,
#                           'Security': 4,
#                           'Variants': 3,
#                           'Naming': 2,
#                           'Hardware_requirements': 2,
#                           'Applications': 3,
#                           'Uses': 2,
#                           'Licensing': 2,
#                           'Design': 1,
#                           'Example': 1,
#                           'Components': 1,
#                           'Editions': 2,
#                           'Reception': 3,
#                           'Version_history': 1,
#                           'Name': 2,
#                           'Use': 1,
#                           'System_requirements': 2,
#                           'Gallery': 1,
#                           'Tools': 1}),
#              'Production': defaultdict(int,
#                          {'Models': 1,
#                           'Hardware': 1,
#                           'Software': 1,
#                           'Plot': 7,
#                           'Overview': 7,
#                           'History': 5,
#                           'Usage': 3,
#                           'Etymology': 1,
#                           'Criticism': 2,
#                           'Awards': 2,
#                           'Features': 1,
#                           'Reception': 19,
#                           'Marketing': 2,
#                           'Release': 8,
#                           'Legacy': 2,
#                           'Background': 2,
#                           'Impact': 1,
#                           'Controversies': 1,
#                           'Release_history': 1}),
#              'Models': defaultdict(int,
#                          {'Production': 1,
#                           'Hardware': 4,
#                           'Software': 5,
#                           'Development': 1,
#                           'Specifications': 1,
#                           'Reception': 4,
#                           'Controversies': 1,
#                           'Technical_specifications': 4,
#                           'Sales': 2,
#                           'Cultural_impact': 1,
#                           'Timeline': 4,
#                           'Features': 2,
# ...
#                           'Implementations': 3,
#                           'Acquisitions': 3,
#                           'Controversies': 3,
#                           'Features': 2,
#                           'Derivatives': 2}),
#              'Standards': defaultdict(int,
#                          {'History': 17,
#                           'Syntax': 3,
#                           'Uses': 3,
#                           'Derivatives': 3,
#                           'Overview': 5,
#                           'Components': 2,
#                           'Impact': 2,
#                           'Naming': 3,
#                           'Adoption': 3,
#                           'Etymology': 3,
#                           'Background': 4,
#                           'Software': 3,
#                           'Origin': 2,
#                           'Other': 2,
#                           'Legacy': 2,
#                           'Use': 3,
#                           'Function': 3,
#                           'Privacy': 3,
#                           'Timeline': 2,
#                           'Design': 2,
#                           'Variants': 2,
#                           'License': 1,
#                           'Security': 5,
#                           'Description': 2,
#                           'History_and_development': 2,
#                           'Versions': 1,
#                           'Types': 2,
#                           'In_popular_culture': 2,
#                           'Applications': 7,
#                           'Devices': 1,
#                           'Interface': 1,
#                           'Operation': 1,
#                           'Development_tools': 1,
#                           'Technologies': 1,
#                           'Characteristics': 1,
#                           'Deployment': 1,
#                           'Technology': 1,
#                           'Example': 1,
#                           'Criticism': 1}),
#              'Derivatives': defaultdict(int,
#                          {'Standards': 3,
#                           'History': 15,
#                           'Syntax': 2,
#                           'Uses': 1,
#                           'Naming': 4,
#                           'Adoption': 2,
#                           'Security': 1,
#                           'Features': 8,
#                           'Development': 5,
#                           'License': 2,
#                           'Version_history': 2,
#                           'Versions': 5,
#                           'Conferences': 2,
#                           'Reception': 4,
#                           'Components': 2,
#                           'Hardware_requirements': 2,
#                           'Popularity': 2,
#                           'Applications': 2,
#                           'Editions': 1,
#                           'Overview': 1,
#                           'Deployment': 1,
#                           'Release_history': 1,
#                           'Usage': 1,
#                           'Legacy': 1}),
#              'Mascot': defaultdict(int,
#                          {'History': 10,
#                           'Syntax': 5,
#                           'Implementations': 5,
#                           'Licensing': 9,
#                           'Use': 5,
#                           'Security': 5,
#                           'Features': 4,
#                           'Hardware': 3,
#                           'Development': 3,
#                           'Security_and_privacy': 3,
#                           'Reception': 3,
#                           'Other_uses': 3,
#                           'Criticisms': 1,
#                           'Usage': 1,
#                           'Criticism': 1}),
#              'Alternatives': defaultdict(int,
#                          {'History': 14,
#                           'Syntax': 3,
#                           'Criticisms': 3,
#                           'Sources': 3,
#                           'Development': 3,
#                           'Introduction': 3,
#                           'Description': 2,
#                           'Properties': 4,
#                           'Applications': 3,
#                           'Variants': 2,
#                           'Examples': 4,
#                           'Usage': 3,
#                           'Criticism': 1,
#                           'Terminology': 2,
#                           'File_format': 3,
#                           'Technical_details': 1,
#                           'Licensing': 1,
#                           'Security': 4,
#                           'Software': 1,
#                           'Uses': 1,
#                           'Hardware': 1,
#                           'Motivation': 1,
#                           'Example': 1,
#                           'Components': 1,
#                           'Versions': 1,
#                           'Compatibility': 1,
#                           'Implementation': 1,
#                           'Technologies': 1,
#                           'Implementations': 1,
#                           'Gallery': 1,
#                           'Overview': 2,
#                           'Advantages': 1}),
#              'Career_and_research': defaultdict(int,
#                          {'Early_life_and_education': 11,
#                           'Personal_life': 8,
#                           'Awards': 3,
#                           'Legacy': 1,
#                           'Education': 1}),
#              'Origin': defaultdict(int,
#                          {'Characteristics': 5,
#                           'Implementation': 4,
#                           'Other': 2,
#                           'Legacy': 3,
#                           'Syntax': 2,
#                           'Standards': 2,
#                           'Example': 1,
#                           'Motivation': 1,
#                           'History': 2,
#                           'Media': 1,
#                           'Types': 1,
#                           'Examples': 1,
#                           'Usage': 3,
#                           'Notable_examples': 2,
#                           'Gameplay': 1,
#                           'Reception': 2,
#                           'Criticism': 1}),
#              'Formal_definition': defaultdict(int,
#                          {'Example': 5,
#                           'Usage': 2,
#                           'Properties': 6,
#                           'Overview': 3,
#                           'Description': 1,
#                           'History': 5,
#                           'Background': 3,
#                           'Naming': 2,
#                           'Examples': 2,
#                           'Applications': 1,
#                           'Variants': 1,
#                           'Implementation': 1,
#                           'Etymology': 1,
#                           'Tools': 1}),
#              'Example': defaultdict(int,
#                          {'Formal_definition': 5,
#                           'Usage': 3,
#                           'Properties': 8,
#                           'History': 23,
#                           'Sources': 2,
#                           'Applications': 7,
#                           'Background': 3,
#                           'Characteristics': 2,
#                           'Limitations': 3,
#                           'Overview': 9,
#                           'Structure': 6,
#                           'Description': 2,
#                           'Advantages': 3,
#                           'Uses': 2,
#                           'Implementations': 2,
#                           'Variants': 3,
#                           'Terminology': 1,
#                           'Implementation': 5,
#                           'Origin': 1,
#                           'Motivation': 3,
#                           'Introduction': 2,
#                           'Alternatives': 1,
#                           'Version_history': 1,
#                           'Problems': 1,
#                           'Theory': 1,
#                           'Purpose': 1,
#                           'Development': 2,
#                           'Criticism': 2,
#                           'Use': 4,
#                           'Syntax': 2,
#                           'Standards': 1,
#                           'Architecture': 2,
#                           'Design': 1,
#                           'Components': 1,
#                           'Releases': 1,
#                           'Functions': 1,
#                           'Other': 1,
#                           'Origins': 1,
#                           'File_format': 1}),
#              'Properties': defaultdict(int,
#                          {'Formal_definition': 6,
#                           'Example': 8,
#                           'Usage': 2,
#                           'Motivation': 2,
#                           'Applications': 15,
#                           'History': 17,
#                           'Implementation': 2,
#                           'Description': 4,
#                           'Variants': 4,
#                           'Overview': 5,
#                           'Background': 5,
#                           'Naming': 2,
#                           'Terminology': 1,
#                           'Introduction': 2,
#                           'Examples': 6,
#                           'Alternatives': 4,
#                           'Features': 1,
#                           'Structure': 1,
#                           'Security': 1,
#                           'Implementations': 1,
#                           'Other': 1}),
#              'Awards': defaultdict(int,
#                          {'Early_life': 2,
#                           'Career': 8,
#                           'Early_life_and_education': 8,
#                           'Career_and_research': 3,
#                           'Personal_life': 10,
#                           'Death': 4,
#                           'Legacy': 5,
#                           'Gallery': 4,
#                           'History': 15,
#                           'Services': 4,
#                           'Conferences': 1,
#                           'Criticism': 3,
#                           'Biography': 6,
#                           'Etymology': 3,
#                           'Production': 2,
#                           'Main_features': 1,
#                           'Variants': 1,
#                           'Licensing': 1,
#                           'Publications': 1,
#                           'Features': 1,
#                           'Security': 1,
#                           'Education': 1,
#                           'Products': 1,
#                           'Corporate_affairs': 1,
#                           'Content': 3,
#                           'Philanthropy': 1,
#                           'Critical_reception': 1,
#                           'Plot': 1,
#                           'Reception': 1,
#                           'In_popular_culture': 1,
#                           'Books': 1,
#                           'Functionality': 1,
#                           'Origins': 1,
#                           'Hardware': 1,
#                           'Problems': 1,
#                           'System_requirements': 1,
#                           'Litigation': 1,
#                           'Controversies': 2}),
#              'Notable_examples': defaultdict(int,
#                          {'History': 2,
#                           'Origins': 1,
#                           'Criticism': 1,
#                           'Origin': 2,
#                           'Usage': 2,
#                           'Overview': 1,
#                           'Description': 1,
#                           'Types': 1}),
#              'Death': defaultdict(int,
#                          {'Early_life_and_education': 3,
#                           'Career': 3,
#                           'Awards_and_honors': 3,
#                           'Legacy': 8,
#                           'Awards': 4,
#                           'Gallery': 4,
#                           'Early_life': 2,
#                           'Philanthropy': 1,
#                           'Personal_life': 1,
#                           'Publications': 1,
#                           'Biography': 1,
#                           'Cultural_impact': 1,
#                           'Background': 1}),
#              'Publications': defaultdict(int,
#                          {'History': 6,
#                           'Biography': 7,
#                           'Programming': 3,
#                           'Personal_life': 6,
#                           'Awards_and_honors': 4,
#                           'Programming_languages': 1,
#                           'In_popular_culture': 1,
#                           'Explanatory_notes': 1,
#                           'Early_life': 1,
#                           'Death': 1,
#                           'Early_life_and_education': 2,
#                           'Career': 3,
#                           'Awards': 1,
#                           'Reception': 4,
#                           'Legacy': 1,
#                           'Other_uses': 1}),
#              'Biography': defaultdict(int,
#                          {'Programming': 3,
#                           'Personal_life': 5,
#                           'Awards_and_honors': 4,
#                           'Publications': 7,
#                           'Awards': 6,
#                           'Programming_languages': 1,
#                           'In_popular_culture': 1,
#                           'Explanatory_notes': 1,
#                           'Controversy': 1,
#                           'Career': 1,
#                           'Honors_and_awards': 1,
#                           'Death': 1,
#                           'Legacy': 1,
#                           'Cultural_impact': 1,
#                           'Influence': 1,
#                           'Books': 1,
#                           'Media': 1,
#                           'Philosophy': 1}),
#              'Corporate_affairs': defaultdict(int,
#                          {'History': 23,
#                           'Criticism_and_controversies': 8,
#                           'Products': 5,
#                           'Controversies': 4,
#                           'Name': 1,
#                           'Technologies': 1,
#                           'Acquisitions': 1,
#                           'Content': 1,
#                           'Awards': 1,
#                           'Criticism': 4,
#                           'Explanatory_notes': 3,
#                           'Usage': 3,
#                           'Features': 1}),
#              'Criticism_and_controversies': defaultdict(int,
#                          {'History': 12,
#                           'Corporate_affairs': 8,
#                           'Products': 2,
#                           'Services': 2,
#                           'Security': 2,
#                           'Litigation': 2,
#                           'Acquisitions': 1,
#                           'Usage': 2}),
#              'Operating_system_support': defaultdict(int,
#                          {'History': 4,
#                           'Licensing': 1,
#                           'Features': 2,
#                           'Etymology': 1,
#                           'Operation': 1,
#                           'Types': 1,
#                           'Applications': 1,
#                           'Design': 1,
#                           'Development_tools': 1,
#                           'Limitations': 1,
#                           'Specifications': 1,
#                           'Background': 1,
#                           'General': 3,
#                           'Release_history': 3,
#                           'Internationalization': 2,
#                           'Privacy': 1,
#                           'Media': 1,
#                           'Description': 1,
#                           'Examples': 1}),
#              'Main_features': defaultdict(int,
#                          {'Security': 2,
#                           'Deployment': 2,
#                           'History': 10,
#                           'Editions': 1,
#                           'Architecture': 1,
#                           'Licensing': 4,
#                           'Variants': 1,
#                           'Awards': 1,
#                           'Version_history': 1})})

# %%
clustered_subtopics
# Out:
# [['Components',
#   'Features',
#   'Applications',
#   'Supported_devices',
#   'Advantages',
#   'System_features',
#   'App_features',
#   'Main_features'],
#  ['Platforms',
#   'Products',
#   'Issues',
#   'Problems',
#   'Syntax',
#   'Functions',
#   'Gameplay',
#   'Other',
#   'Details',
#   'Plot',
#   'Function',
#   'Games',
#   'Name',
#   'Mascot'],
#  ['Criticism',
#   'History',
#   'Background',
#   'Personal_life',
#   'Books',
#   'Early_life',
#   'Philanthropy',
#   'Early_life_and_education',
#   'Changes',
#   'History_and_development',
#   'Etymology',
#   'Origins',
#   'Origin',
#   'Other_uses',
#   'Introduction',
#   'Criticisms',
#   'Education',
#   'Biography',
#   'Death',
#   'Philosophy',
#   'Libraries',
#   'Uses',
#   'Structure',
#   'Topics',
#   'Theory',
#   'Derivatives',
#   'Career_and_research'],
#  ['Version_history',
#   'Release_history',
#   'Releases',
#   'Timeline',
#   'Release',
#   'Editions',
#   'Versions'],
#  ['Hardware',
#   'Development',
#   'Security_and_privacy',
#   'Devices',
#   'Architecture',
#   'Functionality',
#   'Production',
#   'Software',
#   'Design',
#   'Security',
#   'Programming',
#   'User_interface',
#   'Programming_languages',
#   'Technologies',
#   'Technology',
#   'Interface',
#   'Storage',
#   'Development_tools',
#   'Mitigation',
#   'Operating_system_support',
#   'Privacy',
#   'Services',
#   'Tools',
#   'Terminology',
#   'Alternatives'],
#  ['Reception',
#   'Honors_and_awards',
#   'Awards_and_honors',
#   'General',
#   'Operation',
#   'Awards'],
#  ['Usage',
#   'File_format',
#   'System_requirements',
#   'Specifications',
#   'Gallery',
#   'Variants',
#   'Standards',
#   'Sales',
#   'Technical_specifications',
#   'Description',
#   'Compatibility',
#   'Media',
#   'Availability',
#   'Use',
#   'Hardware_requirements',
#   'Types',
#   'Conferences'],
#  ['Implementation',
#   'Corporate_affairs',
#   'Purpose',
#   'Limitations',
#   'Legality',
#   'Acquisitions',
#   'Litigation',
#   'Censorship',
#   'Technical_details',
#   'License',
#   'Implementations',
#   'Licensing',
#   'Naming',
#   'Deployment',
#   'Adoption',
#   'Publications',
#   'Trademark',
#   'Formal_definition',
#   'Properties'],
#  ['In_popular_culture',
#   'Models',
#   'Cultural_impact',
#   'Career',
#   'Controversies',
#   'Controversy',
#   'Market_share',
#   'Legacy',
#   'Motivation',
#   'Internationalization',
#   'Influence',
#   'Critical_reception',
#   'Impact',
#   'Marketing',
#   'Content',
#   'Characteristics',
#   'Popularity'],
#  ['Criticism_and_controversies',
#   'Overview',
#   'Notable_examples',
#   'Sources',
#   'Explanatory_notes',
#   'Citations',
#   'Examples',
#   'Example']]

# %%
cooccurence_list = []

# %%
for key, dic in co_occurence.items():
    for cluster in clustered_subtopics:
        if key in cluster:
            total_freq = sum(dic.values())
            in_cluster = 0
            not_in_cluster = 0
            for k, v in dic.items():
                if k in cluster:
                    in_cluster += v
                else:
                    not_in_cluster += v
    cooccurence_list.append({'subtopic': key, 'total_freq': total_freq, \
                             'in_cluster': in_cluster, 'not_in_cluster': not_in_cluster})

# %%
cooccurence_list
# Out:
# [{'subtopic': 'Components',
#   'total_freq': 132,
#   'in_cluster': 14,
#   'not_in_cluster': 118},
#  {'subtopic': 'Platforms',
#   'total_freq': 87,
#   'in_cluster': 0,
#   'not_in_cluster': 87},
#  {'subtopic': 'Criticism',
#   'total_freq': 393,
#   'in_cluster': 152,
#   'not_in_cluster': 241},
#  {'subtopic': 'Version_history',
#   'total_freq': 114,
#   'in_cluster': 2,
#   'not_in_cluster': 112},
#  {'subtopic': 'History',
#   'total_freq': 3523,
#   'in_cluster': 351,
#   'not_in_cluster': 3172},
#  {'subtopic': 'Architecture',
#   'total_freq': 156,
#   'in_cluster': 17,
#   'not_in_cluster': 139},
#  {'subtopic': 'Features',
#   'total_freq': 1047,
#   'in_cluster': 29,
#   'not_in_cluster': 1018},
#  {'subtopic': 'Release_history',
#   'total_freq': 189,
#   'in_cluster': 1,
#   'not_in_cluster': 188},
#  {'subtopic': 'Reception',
#   'total_freq': 905,
#   'in_cluster': 8,
#   'not_in_cluster': 897},
#  {'subtopic': 'Functionality',
#   'total_freq': 49,
#   'in_cluster': 11,
#   'not_in_cluster': 38},
#  {'subtopic': 'Implementation',
#   'total_freq': 167,
#   'in_cluster': 14,
#   'not_in_cluster': 153},
#  {'subtopic': 'Hardware',
#   'total_freq': 209,
#   'in_cluster': 54,
#   'not_in_cluster': 155},
#  {'subtopic': 'Development',
#   'total_freq': 372,
#   'in_cluster': 45,
#   'not_in_cluster': 327},
#  {'subtopic': 'Security_and_privacy',
#   'total_freq': 66,
#   'in_cluster': 19,
#   'not_in_cluster': 47},
#  {'subtopic': 'Devices',
#   'total_freq': 45,
#   'in_cluster': 9,
#   'not_in_cluster': 36},
#  {'subtopic': 'Usage',
#   'total_freq': 185,
#   'in_cluster': 7,
#   'not_in_cluster': 178},
#  {'subtopic': 'Background',
#   'total_freq': 157,
#   'in_cluster': 36,
#   'not_in_cluster': 121},
#  {'subtopic': 'Personal_life',
#   'total_freq': 225,
#   'in_cluster': 122,
#   'not_in_cluster': 103},
#  {'subtopic': 'Honors_and_awards',
#   'total_freq': 31,
#   'in_cluster': 0,
#   'not_in_cluster': 31},
#  {'subtopic': 'In_popular_culture',
#   'total_freq': 144,
#   'in_cluster': 13,
#   'not_in_cluster': 131},
#  {'subtopic': 'Books',
#   'total_freq': 32,
#   'in_cluster': 23,
#   'not_in_cluster': 9},
#  {'subtopic': 'Releases',
#   'total_freq': 83,
#   'in_cluster': 3,
#   'not_in_cluster': 80},
#  {'subtopic': 'Production',
#   'total_freq': 67,
#   'in_cluster': 2,
#   'not_in_cluster': 65},
#  {'subtopic': 'Models',
#   'total_freq': 59,
#   'in_cluster': 3,
#   'not_in_cluster': 56},
#  {'subtopic': 'Software',
#   'total_freq': 209,
#   'in_cluster': 49,
#   'not_in_cluster': 160},
#  {'subtopic': 'File_format',
#   'total_freq': 29,
#   'in_cluster': 2,
#   'not_in_cluster': 27},
#  {'subtopic': 'Cultural_impact',
#   'total_freq': 28,
#   'in_cluster': 2,
#   'not_in_cluster': 26},
#  {'subtopic': 'Early_life_and_education',
#   'total_freq': 134,
#   'in_cluster': 67,
#   'not_in_cluster': 67},
#  {'subtopic': 'Career',
#   'total_freq': 180,
#   'in_cluster': 9,
#   'not_in_cluster': 171},
#  {'subtopic': 'Awards_and_honors',
#   'total_freq': 40,
#   'in_cluster': 0,
#   'not_in_cluster': 40},
#  {'subtopic': 'Changes',
#   'total_freq': 40,
#   'in_cluster': 6,
#   'not_in_cluster': 34},
#  {'subtopic': 'System_requirements',
#   'total_freq': 111,
#   'in_cluster': 6,
#   'not_in_cluster': 105},
#  {'subtopic': 'Design',
#   'total_freq': 322,
#   'in_cluster': 48,
#   'not_in_cluster': 274},
#  {'subtopic': 'Problems',
#   'total_freq': 90,
#   'in_cluster': 0,
#   'not_in_cluster': 90},
#  {'subtopic': 'Variants',
#   'total_freq': 103,
#   'in_cluster': 13,
#   'not_in_cluster': 90},
#  {'subtopic': 'Gallery',
#   'total_freq': 54,
#   'in_cluster': 8,
#   'not_in_cluster': 46},
#  {'subtopic': 'Timeline',
#   'total_freq': 118,
#   'in_cluster': 2,
#   'not_in_cluster': 116},
#  {'subtopic': 'Early_life',
#   'total_freq': 103,
#   'in_cluster': 54,
#   'not_in_cluster': 49},
#  {'subtopic': 'Philanthropy',
#   'total_freq': 44,
#   'in_cluster': 31,
#   'not_in_cluster': 13},
#  {'subtopic': 'Specifications',
#   'total_freq': 100,
#   'in_cluster': 7,
#   'not_in_cluster': 93},
#  {'subtopic': 'Controversies',
#   'total_freq': 181,
#   'in_cluster': 15,
#   'not_in_cluster': 166},
#  {'subtopic': 'Overview',
#   'total_freq': 584,
#   'in_cluster': 38,
#   'not_in_cluster': 546},
#  {'subtopic': 'Issues',
#   'total_freq': 55,
#   'in_cluster': 0,
#   'not_in_cluster': 55},
#  {'subtopic': 'Controversy',
#   'total_freq': 59,
#   'in_cluster': 4,
#   'not_in_cluster': 55},
#  {'subtopic': 'History_and_development',
#   'total_freq': 26,
#   'in_cluster': 3,
#   'not_in_cluster': 23},
#  {'subtopic': 'Security',
#   'total_freq': 368,
#   'in_cluster': 52,
#   'not_in_cluster': 316},
#  {'subtopic': 'Market_share',
#   'total_freq': 68,
#   'in_cluster': 2,
#   'not_in_cluster': 66},
#  {'subtopic': 'System_features',
#   'total_freq': 84,
#   'in_cluster': 35,
#   'not_in_cluster': 49},
#  {'subtopic': 'App_features',
#   'total_freq': 84,
#   'in_cluster': 35,
#   'not_in_cluster': 49},
#  {'subtopic': 'Supported_devices',
#   'total_freq': 102,
#   'in_cluster': 39,
#   'not_in_cluster': 63},
#  {'subtopic': 'Programming',
#   'total_freq': 28,
#   'in_cluster': 3,
#   'not_in_cluster': 25},
#  {'subtopic': 'Sales',
#   'total_freq': 53,
#   'in_cluster': 12,
#   'not_in_cluster': 41},
#  {'subtopic': 'Applications',
#   'total_freq': 474,
#   'in_cluster': 21,
#   'not_in_cluster': 453},
#  {'subtopic': 'Etymology',
#   'total_freq': 121,
#   'in_cluster': 51,
#   'not_in_cluster': 70},
#  {'subtopic': 'Purpose',
#   'total_freq': 36,
#   'in_cluster': 2,
#   'not_in_cluster': 34},
#  {'subtopic': 'Technical_specifications',
#   'total_freq': 35,
#   'in_cluster': 4,
#   'not_in_cluster': 31},
#  {'subtopic': 'Description',
#   'total_freq': 123,
#   'in_cluster': 10,
#   'not_in_cluster': 113},
#  {'subtopic': 'User_interface',
#   'total_freq': 51,
#   'in_cluster': 18,
#   'not_in_cluster': 33},
#  {'subtopic': 'Motivation',
#   'total_freq': 31,
#   'in_cluster': 1,
#   'not_in_cluster': 30},
#  {'subtopic': 'Legality',
#   'total_freq': 17,
#   'in_cluster': 0,
#   'not_in_cluster': 17},
#  {'subtopic': 'Advantages',
#   'total_freq': 58,
#   'in_cluster': 7,
#   'not_in_cluster': 51},
#  {'subtopic': 'Compatibility',
#   'total_freq': 49,
#   'in_cluster': 4,
#   'not_in_cluster': 45},
#  {'subtopic': 'Censorship',
#   'total_freq': 56,
#   'in_cluster': 4,
#   'not_in_cluster': 52},
#  {'subtopic': 'Internationalization',
#   'total_freq': 27,
#   'in_cluster': 0,
#   'not_in_cluster': 27},
#  {'subtopic': 'Technical_details',
#   'total_freq': 43,
#   'in_cluster': 5,
#   'not_in_cluster': 38},
#  {'subtopic': 'Content',
#   'total_freq': 73,
#   'in_cluster': 2,
#   'not_in_cluster': 71},
#  {'subtopic': 'Legacy',
#   'total_freq': 165,
#   'in_cluster': 10,
#   'not_in_cluster': 155},
#  {'subtopic': 'Programming_languages',
#   'total_freq': 14,
#   'in_cluster': 1,
#   'not_in_cluster': 13},
#  {'subtopic': 'General',
#   'total_freq': 19,
#   'in_cluster': 1,
#   'not_in_cluster': 18},
#  {'subtopic': 'Technology',
#   'total_freq': 123,
#   'in_cluster': 8,
#   'not_in_cluster': 115},
#  {'subtopic': 'Influence',
#   'total_freq': 24,
#   'in_cluster': 2,
#   'not_in_cluster': 22},
#  {'subtopic': 'Syntax',
#   'total_freq': 177,
#   'in_cluster': 7,
#   'not_in_cluster': 170},
#  {'subtopic': 'Media',
#   'total_freq': 28,
#   'in_cluster': 0,
#   'not_in_cluster': 28},
#  {'subtopic': 'Technologies',
#   'total_freq': 77,
#   'in_cluster': 6,
#   'not_in_cluster': 71},
#  {'subtopic': 'Acquisitions',
#   'total_freq': 54,
#   'in_cluster': 3,
#   'not_in_cluster': 51},
#  {'subtopic': 'Litigation',
#   'total_freq': 35,
#   'in_cluster': 3,
#   'not_in_cluster': 32},
#  {'subtopic': 'Availability',
#   'total_freq': 54,
#   'in_cluster': 3,
#   'not_in_cluster': 51},
#  {'subtopic': 'Gameplay',
#   'total_freq': 47,
#   'in_cluster': 5,
#   'not_in_cluster': 42},
#  {'subtopic': 'Release',
#   'total_freq': 46,
#   'in_cluster': 0,
#   'not_in_cluster': 46},
#  {'subtopic': 'Origins',
#   'total_freq': 51,
#   'in_cluster': 8,
#   'not_in_cluster': 43},
#  {'subtopic': 'Use',
#   'total_freq': 119,
#   'in_cluster': 14,
#   'not_in_cluster': 105},
#  {'subtopic': 'License',
#   'total_freq': 63,
#   'in_cluster': 3,
#   'not_in_cluster': 60},
#  {'subtopic': 'Implementations',
#   'total_freq': 247,
#   'in_cluster': 24,
#   'not_in_cluster': 223},
#  {'subtopic': 'Interface',
#   'total_freq': 18,
#   'in_cluster': 3,
#   'not_in_cluster': 15},
#  {'subtopic': 'Functions',
#   'total_freq': 20,
#   'in_cluster': 0,
#   'not_in_cluster': 20},
#  {'subtopic': 'Other',
#   'total_freq': 28,
#   'in_cluster': 2,
#   'not_in_cluster': 26},
#  {'subtopic': 'Critical_reception',
#   'total_freq': 22,
#   'in_cluster': 4,
#   'not_in_cluster': 18},
#  {'subtopic': 'Storage',
#   'total_freq': 35,
#   'in_cluster': 9,
#   'not_in_cluster': 26},
#  {'subtopic': 'Details',
#   'total_freq': 11,
#   'in_cluster': 0,
#   'not_in_cluster': 11},
#  {'subtopic': 'Examples',
#   'total_freq': 283,
#   'in_cluster': 15,
#   'not_in_cluster': 268},
#  {'subtopic': 'Plot', 'total_freq': 40, 'in_cluster': 6, 'not_in_cluster': 34},
#  {'subtopic': 'Editions',
#   'total_freq': 73,
#   'in_cluster': 4,
#   'not_in_cluster': 69},
#  {'subtopic': 'Licensing',
#   'total_freq': 177,
#   'in_cluster': 13,
#   'not_in_cluster': 164},
#  {'subtopic': 'Naming',
#   'total_freq': 76,
#   'in_cluster': 12,
#   'not_in_cluster': 64},
#  {'subtopic': 'Impact',
#   'total_freq': 71,
#   'in_cluster': 1,
#   'not_in_cluster': 70},
#  {'subtopic': 'Mitigation',
#   'total_freq': 37,
#   'in_cluster': 0,
#   'not_in_cluster': 37},
#  {'subtopic': 'Other_uses',
#   'total_freq': 53,
#   'in_cluster': 9,
#   'not_in_cluster': 44},
#  {'subtopic': 'Limitations',
#   'total_freq': 173,
#   'in_cluster': 12,
#   'not_in_cluster': 161},
#  {'subtopic': 'Versions',
#   'total_freq': 131,
#   'in_cluster': 2,
#   'not_in_cluster': 129},
#  {'subtopic': 'Introduction',
#   'total_freq': 64,
#   'in_cluster': 13,
#   'not_in_cluster': 51},
#  {'subtopic': 'Function',
#   'total_freq': 35,
#   'in_cluster': 0,
#   'not_in_cluster': 35},
#  {'subtopic': 'Marketing',
#   'total_freq': 40,
#   'in_cluster': 9,
#   'not_in_cluster': 31},
#  {'subtopic': 'Games',
#   'total_freq': 29,
#   'in_cluster': 3,
#   'not_in_cluster': 26},
#  {'subtopic': 'Education',
#   'total_freq': 33,
#   'in_cluster': 23,
#   'not_in_cluster': 10},
#  {'subtopic': 'Services',
#   'total_freq': 86,
#   'in_cluster': 12,
#   'not_in_cluster': 74},
#  {'subtopic': 'Criticisms',
#   'total_freq': 59,
#   'in_cluster': 22,
#   'not_in_cluster': 37},
#  {'subtopic': 'Products',
#   'total_freq': 67,
#   'in_cluster': 1,
#   'not_in_cluster': 66},
#  {'subtopic': 'Operation',
#   'total_freq': 115,
#   'in_cluster': 6,
#   'not_in_cluster': 109},
#  {'subtopic': 'Name', 'total_freq': 80, 'in_cluster': 1, 'not_in_cluster': 79},
#  {'subtopic': 'Development_tools',
#   'total_freq': 36,
#   'in_cluster': 8,
#   'not_in_cluster': 28},
#  {'subtopic': 'Privacy',
#   'total_freq': 54,
#   'in_cluster': 9,
#   'not_in_cluster': 45},
#  {'subtopic': 'Deployment',
#   'total_freq': 24,
#   'in_cluster': 2,
#   'not_in_cluster': 22},
#  {'subtopic': 'Adoption',
#   'total_freq': 160,
#   'in_cluster': 24,
#   'not_in_cluster': 136},
#  {'subtopic': 'Hardware_requirements',
#   'total_freq': 35,
#   'in_cluster': 0,
#   'not_in_cluster': 35},
#  {'subtopic': 'Tools',
#   'total_freq': 69,
#   'in_cluster': 6,
#   'not_in_cluster': 63},
#  {'subtopic': 'Trademark',
#   'total_freq': 49,
#   'in_cluster': 6,
#   'not_in_cluster': 43},
#  {'subtopic': 'Philosophy',
#   'total_freq': 40,
#   'in_cluster': 17,
#   'not_in_cluster': 23},
#  {'subtopic': 'Explanatory_notes',
#   'total_freq': 84,
#   'in_cluster': 12,
#   'not_in_cluster': 72},
#  {'subtopic': 'Citations',
#   'total_freq': 51,
#   'in_cluster': 10,
#   'not_in_cluster': 41},
#  {'subtopic': 'Sources',
#   'total_freq': 196,
#   'in_cluster': 19,
#   'not_in_cluster': 177},
#  {'subtopic': 'Characteristics',
#   'total_freq': 104,
#   'in_cluster': 8,
#   'not_in_cluster': 96},
#  {'subtopic': 'Libraries',
#   'total_freq': 46,
#   'in_cluster': 15,
#   'not_in_cluster': 31},
#  {'subtopic': 'Uses',
#   'total_freq': 213,
#   'in_cluster': 76,
#   'not_in_cluster': 137},
#  {'subtopic': 'Popularity',
#   'total_freq': 53,
#   'in_cluster': 1,
#   'not_in_cluster': 52},
#  {'subtopic': 'Types',
#   'total_freq': 228,
#   'in_cluster': 17,
#   'not_in_cluster': 211},
#  {'subtopic': 'Topics',
#   'total_freq': 25,
#   'in_cluster': 8,
#   'not_in_cluster': 17},
#  {'subtopic': 'Terminology',
#   'total_freq': 132,
#   'in_cluster': 16,
#   'not_in_cluster': 116},
#  {'subtopic': 'Structure',
#   'total_freq': 114,
#   'in_cluster': 56,
#   'not_in_cluster': 58},
#  {'subtopic': 'Theory',
#   'total_freq': 33,
#   'in_cluster': 11,
#   'not_in_cluster': 22},
#  {'subtopic': 'Conferences',
#   'total_freq': 51,
#   'in_cluster': 0,
#   'not_in_cluster': 51},
#  {'subtopic': 'Standards',
#   'total_freq': 104,
#   'in_cluster': 9,
#   'not_in_cluster': 95},
#  {'subtopic': 'Derivatives',
#   'total_freq': 70,
#   'in_cluster': 16,
#   'not_in_cluster': 54},
#  {'subtopic': 'Mascot',
#   'total_freq': 61,
#   'in_cluster': 5,
#   'not_in_cluster': 56},
#  {'subtopic': 'Alternatives',
#   'total_freq': 74,
#   'in_cluster': 12,
#   'not_in_cluster': 62},
#  {'subtopic': 'Career_and_research',
#   'total_freq': 24,
#   'in_cluster': 20,
#   'not_in_cluster': 4},
#  {'subtopic': 'Origin',
#   'total_freq': 34,
#   'in_cluster': 3,
#   'not_in_cluster': 31},
#  {'subtopic': 'Formal_definition',
#   'total_freq': 34,
#   'in_cluster': 9,
#   'not_in_cluster': 25},
#  {'subtopic': 'Example',
#   'total_freq': 120,
#   'in_cluster': 11,
#   'not_in_cluster': 109},
#  {'subtopic': 'Properties',
#   'total_freq': 90,
#   'in_cluster': 11,
#   'not_in_cluster': 79},
#  {'subtopic': 'Awards',
#   'total_freq': 104,
#   'in_cluster': 1,
#   'not_in_cluster': 103},
#  {'subtopic': 'Notable_examples',
#   'total_freq': 11,
#   'in_cluster': 1,
#   'not_in_cluster': 10},
#  {'subtopic': 'Death',
#   'total_freq': 33,
#   'in_cluster': 9,
#   'not_in_cluster': 24},
#  {'subtopic': 'Publications',
#   'total_freq': 43,
#   'in_cluster': 0,
#   'not_in_cluster': 43},
#  {'subtopic': 'Biography',
#   'total_freq': 38,
#   'in_cluster': 8,
#   'not_in_cluster': 30},
#  {'subtopic': 'Corporate_affairs',
#   'total_freq': 56,
#   'in_cluster': 1,
#   'not_in_cluster': 55},
#  {'subtopic': 'Criticism_and_controversies',
#   'total_freq': 31,
#   'in_cluster': 0,
#   'not_in_cluster': 31},
#  {'subtopic': 'Operating_system_support',
#   'total_freq': 28,
#   'in_cluster': 3,
#   'not_in_cluster': 25},
#  {'subtopic': 'Main_features',
#   'total_freq': 23,
#   'in_cluster': 0,
#   'not_in_cluster': 23}]

# %%
cooccurence_score = []

# %%
for i in cooccurence_list:
    cooccurence_score.append(i['in_cluster']/i['total_freq'])

# %%
# Lower is better
np.average(cooccurence_score)
# Out:
# 0.14201563648524493
